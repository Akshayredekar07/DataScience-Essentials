# %% [markdown]
# ### **Install Requirements**

# %%
# ! python -m ipykernel install --user --name=webscrape_env --display-name "Web Scraping Env"

# %%
# ! uv pip install --system pandas numpy requests beautifulsoup4 lxml html5lib selenium webdriver-manager jupyter ipykernel chromedriver-autoinstaller
